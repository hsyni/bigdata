# %%
import numpy as np
X = np.arange(0,100)
Y = np.random.randint(0,200, size=X.shape[0])

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.plot(X,Y)

# %%
import pandas as pd
df = pd.DataFrame({'x':X, 'y_col':Y})

# %%
plt.plot('x', 'y_col', data=df)

# %%
df.plot('x', 'y_col')
# Out:
# <AxesSubplot:xlabel='x'>

# %%
import seaborn as sns
sns.lineplot(X,Y)
sns.lineplot('x', 'y_col', data=df)
# Out:
# C:\Users\Huseyin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Huseyin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='x', ylabel='y_col'>
